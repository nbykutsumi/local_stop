# %%
import numpy as np
import pylab as pl
import tensorflow as tf
import matplotlib.gridspec as gridspec
from sklearn.decomposition import PCA, IncrementalPCA
import matplotlib.pyplot as plt
# %matplotlib inline


#train = np.concatenate([ np.loadtxt('train3_12345.txt' ), 
#                         np.loadtxt('train3_6789.txt'  ), 
#                         np.loadtxt('train3_101112.txt')])
#label = np.concatenate([ np.loadtxt('label3_12345.txt' ), 
#                         np.loadtxt('label3_6789.txt'  ), 
#                         np.loadtxt('label3_101112.txt')]).reshape(-1,1)

train = np.concatenate([ np.loadtxt('train3_12345.txt' )]) 
label = np.concatenate([ np.loadtxt('label3_12345.txt' )]).reshape(-1,1)

train.shape, label.shape
# Out:
# ((43061, 273), (43061, 1))

# %%
cov = 1/len(train)*np.dot((train-train.mean(0)).T, train-train.mean(0))
u,s,v = np.linalg.svd(cov)
restriction = 39
print(s[:restriction].sum()/s.sum())
U = u[:,:restriction]
reduction = np.dot(train, U)
Max, Min = np.max(label), np.min(label)
print(reduction.shape)
# Out:
# nan
# (43061, 39)
# /home/utsumi/miniconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.

# %%
ncomb= train.shape[1]
pca = PCA(n_components=ncomb)
pca.fit(train)
components = pca.components_
reduction_pca0 = pca.fit_transform(train)[:,:restriction]
varratio   = pca.explained_variance_ratio_
cumvarratio=np.cumsum(varratio)

reduction_pca0b= np.dot(train, components[:restriction].T)
print train.min(),train.max()
print reduction_pca0.min(), reduction_pca0.max()
print reduction_pca0b.min(), reduction_pca0b.max()
print components.shape
print reduction_pca0.shape, reduction_pca0b.shape
plt.plot(reduction_pca0[:,0],reduction_pca0[:,1],'.',color='r')
#plt.figure();plt.plot(reduction_pca0[:,0],reduction_pca0b[:,2],'.',color='b')
#plt.figure();plt.plot(reduction_pca0[:,0],reduction_pca0b[:,restriction-1],'.',color='b')
# Out:
# 55.040000915527344 329.94000244140625
# -610.5218194380764 1383.711801689532
# -3320.639962466242 679.4942919440876
# (273, 273)
# (43061, 39) (43061, 39)

# %%
m = train.mean(axis=0)
s = train.std(axis=0)
#X = (train-m)/s
X = (train-m)
ncomb= X.shape[1]
pca = PCA(n_components=ncomb)
pca.fit(X)
components = pca.components_
#reduction_pca0 = pca.fit_transform(X)[:,:restriction]
reduction_pca0 = pca.fit_transform(X+m)[:,:restriction]
varratio   = pca.explained_variance_ratio_
cumvarratio=np.cumsum(varratio)

#reduction_pca0b= np.dot(X, components[:restriction].T)
reduction_pca0b= np.dot(X+m, components[:restriction].T)
print X.min(),X.max()
print reduction_pca0.min(), reduction_pca0.max()
print reduction_pca0b.min(), reduction_pca0b.max()
print components.shape
print reduction_pca0.shape, reduction_pca0b.shape
plt.plot(reduction_pca0[:,0],reduction_pca0[:,1],'.',color='r')
plt.figure();plt.plot(reduction_pca0[:,0],reduction_pca0[:,2],'.',color='r')
plt.figure();plt.plot(reduction_pca0[:,0],reduction_pca0[:,restriction-1],'.',color='r')
#plt.figure();plt.plot(reduction_pca0b[:,0],reduction_pca0b[:,1],'.',color='b')
#print components
print np.dot(reduction_pca0[:,0], reduction_pca0[:,1].T)
# Out:
# -191.11740498956826 71.21469535941915
# -610.521819438076 1383.711801689531
#   6.09801993  7.17989073  6.3441842   8.95328734  9.47592847 23.33270428
#  24.1502475  33.2824226  34.28140741 24.6939501  31.5267632   6.65882278
#   8.5965755   6.09005539  7.19994083  6.30428553  8.87578412  9.40871501
#  23.19985104 24.04393783 33.19933361 34.2279215  24.58680693 31.4259795
#   6.71437658  8.69725985  6.10553345  7.255306    6.27972189  8.73677576
#   9.30029072 22.95861926 23.88276394 33.05174409 34.18044632 24.25367302
#  31.14477307  6.79813899  8.85465539  6.14360137  7.33134845  6.2816456
#   8.63461003  9.24602678 22.75859118 23.8300529  32.98087198 34.30411722
#  23.77614367 30.77436746  6.80956156  9.00575169  6.25331097  7.50928975
#   6.49549016  9.09633451  9.71371599 23.61996474 24.83499059 34.01964199
#  35.62558033 23.88665895 31.2094859   6.74038073  8.84793652  6.2046411
#   7.40705044  6.44248611  9.04674     9.63461772 23.59892405 24.69964102
#  33.97732646 35.40057594 24.31169321 31.4859378   6.71104501  8.77471651
#   6.18127587  7.34555029  6.43137301  9.067011    9.63649703 23.66480276
#  24.69121879 33.9292875  35.23991809 24.55853666 31.63502205  6.71401971
#   8.77006963  6.17255627  7.32216803  6.43978682  9.09560134  9.65607176
#  23.64311462 24.64831276 33.85675274 35.12900478 24.63353854 31.65323374
#   6.74534953  8.83060759  6.1660895   7.33338538  6.41453958  9.03676052
#   9.60505377 23.50126738 24.53195572 33.70767789 35.00763997 24.50404082
#  31.49529006  6.80926805  8.9559803   6.18530871  7.38912835  6.40045798
#   8.93406739  9.52342489 23.29633556 24.39623485 33.53361897 34.93029338
#  24.17909299 31.19582124  6.91564743  9.17192327  6.23166978  7.49057007
#   6.41082342  8.87811429  9.50781057 23.20905585 24.41903004 33.45494512
#  35.02297589 23.74489472 30.84951791]
# (43061, 273)

# %%
def FFN(TraX, TraY, TesX, TesY, learning_rate, epochs, batch_size, dim, act): 
    fn1 = tf.nn.sigmoid
    fn2 = tf.nn.relu
    def fn3(x):
        return x/(1+np.abs(x))
    ac  = [fn1,fn3,fn1,fn3,fn1,fn1,fn1,fn1,fn1,fn1,fn1,fn1,fn1,fn1] # number of entry = len(dim) - 2
    total_batch = int(len(TraX)/batch_size) + 1
    Xdata = [ TraX[i*batch_size:(i+1)*batch_size] for i in range(total_batch) ]
    Ydata = [ TraY[i*batch_size:(i+1)*batch_size] for i in range(total_batch) ]
    
    tf.reset_default_graph()
    X = tf.placeholder(tf.float32, [None, TraX.shape[1]])
    Y = tf.placeholder(tf.float32, [None, TraY.shape[1]])
        
    W = [ tf.Variable(tf.random_normal([dim[i], dim[i+1]])) for i in range(len(dim) - 1) ]
    b = [ tf.Variable(tf.random_normal([dim[i+1]]))         for i in range(len(dim) - 1) ]
    A = [ X ]
    for i in range(len(dim) - 2):
        A.append(ac[i](tf.matmul(A[-1], W[i]) + b[i]))
    A.append(tf.matmul(A[-1], W[-1]) + b[-1])  
    if act == 0:
        cost = tf.sqrt(tf.reduce_mean(tf.reduce_mean(tf.square(Y - A[-1]) ))) 
    if act == 1:
        cost = tf.sqrt(tf.reduce_mean(tf.reduce_mean(tf.square(Y - A[-1])*error_function(Y,label,100,12,1,5) ))) 
    gogo = tf.train.AdamOptimizer(learning_rate).minimize(cost)
    real = tf.placeholder(tf.float32, [None, TraY.shape[1]])
    pred = tf.placeholder(tf.float32, [None, TraY.shape[1]])
    rmse = tf.sqrt(tf.reduce_mean(tf.reduce_mean(tf.square(real - pred))))
    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    for epoch in range(epochs):    
        for i in range(total_batch):
            feed1 = {X:Xdata[i], Y:Ydata[i]}
            sess.run(gogo, feed_dict = feed1)
            training_error = sess.run(cost, feed_dict = feed1)
            prediction     = sess.run(A[-1], feed_dict = {X:TesX})
            test_error     = sess.run(rmse, feed_dict = {real:TesY, pred:prediction})
        if epoch % int(epochs/5) == 0:    
            print('Training Error:',training_error,'and','Testing Error:', test_error)
    return prediction
def Figure(Label, Prediction, bins):
    recover_testY = (Max-Min)*Label.flatten()      + Min
    recover_pred  = (Max-Min)*Prediction.flatten() + Min
    pl.figure(figsize=(15,15))
    gs = gridspec.GridSpec(2,2, width_ratios=[1,1], height_ratios=[1,1])
    
    pl.subplot(gs[0,:])
    pl.plot(recover_testY/1000, c='r', label ='Observation')
    pl.plot(recover_pred /1000, c='b', label ='Prediction')
    pl.ylabel('height(km)')
    pl.legend()
    print('RMSE:'     , np.round(rmse(Label, Prediction) , 4))
    print('real RMSE:', np.round(Rmse(Label, Prediction) , 4))
    print('CC:'       , np.round(  cc(Label, Prediction) , 4))
    
    pl.subplot(gs[2]) # values prediction and testY are between -4 and 4
    aa = recover_pred
    bb = recover_testY
    interval           = np.array([ Min + (Max - Min)/bins*i for i in range(bins+1) ])
    interval1          = np.array([ Min + (Max - Min)/bins*i for i in range(bins+1) ])
    revised_interval   = interval[:-1]  + (Max - Min)/(2*bins)
    revised_interval1  = interval1[:-1] + (Max - Min)/(2*bins)
    cumulative_number  = []
    cumulative_number1 = []
    for i in range(bins):
        cumulative_number.append(  (aa < interval[i+1] ).sum() - (aa < interval[i] ).sum() )
        cumulative_number1.append( (bb < interval1[i+1]).sum() - (bb < interval1[i]).sum() )
    pl.plot(revised_interval/1000          , cumulative_number   , color='green', alpha=0.5, label='Prediction')    
    pl.fill_between(revised_interval/1000  , cumulative_number, 0, color='green', alpha=0.5)
    pl.plot(revised_interval1/1000         , cumulative_number1  , color='red'  , alpha=0.5 ,label='Observation')    
    pl.fill_between(revised_interval1/1000 ,cumulative_number1, 0, color='red'  , alpha=0.5)
    pl.ylabel('number of samples')
    pl.xlabel('height(km)')
    pl.legend() 
    pl.title('Distribution')
    pl.legend()
    
    pl.subplot(gs[3])
    pl.scatter(recover_testY/1000, recover_pred/1000,s=3)
    pl.plot(np.arange(18000)/1000,np.arange(18000)/1000,c='black',linestyle = ':')
    pl.axis([0,18,0,18])
    pl.xticks([0,5,10,15])
    pl.yticks([0,5,10,15])
    pl.xlabel('Observation(km)')
    pl.ylabel('Prediction(km)')
    pl.title('Correlation')
    pl.grid()
def error_function(x, data, bins, degree, Min, Max):
    vec       = ((data - np.min(data,0))/(np.max(data,0)-np.min(data,0)))
    interval  = [ i/bins for i in range(bins + 1)]
    frequency = np.array([ ((vec<=interval[i+1]).sum() - (vec<interval[i]).sum())/len(vec) for i in range(bins) ])
    xx        = np.arange(bins)/(bins - 1)
    mat       = np.concatenate([(xx**i).reshape(-1,1) for i in range(degree)], axis=1)
    coef      = np.dot(np.linalg.inv(np.dot(mat.T,mat)), np.dot(mat.T, frequency))
    poly      = 1 - sum([coef[i]*(x**i) for i in range(degree)])
    values    = 1 - sum([coef[i]*(xx**i) for i in range(degree)])
    M, N      = np.max(values), np.min(values)
    return (Max - Min)/(M - N)*(poly - N) + Min 
def uniformize(reduction, label):
    mat = np.concatenate([reduction, label], axis=1)
    temporary = []
    for i in range(mat.shape[1]):
        a = np.arange(len(mat)).reshape(-1,1)
        b = np.concatenate([a,mat[:,[i]]], axis=1)
        c = b[b[:,1].argsort()]
        c[:,1] = np.arange(len(mat))/(len(mat)-1)
        d = c[c[:,0].argsort()]
        temporary.append(d[:,1])
    input_data = (np.array(temporary).T)[:, :-1]
    target     = (np.array(temporary).T)[:,[-1]]
    return input_data, target
def rmse(x,y):
    x = x.flatten()
    y = y.flatten()
    return np.sqrt((((x-y))**2).mean())
def Rmse(x,y):
    return np.sqrt( ( ( ((Max-Min)*x+Min).flatten()-((Max-Min)*y+Min).flatten() )**2 ).mean() )
def cc(x,y):
    return np.corrcoef( x.flatten(), y.flatten() )[0,1]
def sort(x):
    return np.sort(x.flatten())
def unit(x):
    return (x-np.min(x,0))/(np.max(x,0)-np.min(x,0))
def f_act(x):
    degree = 12
    y_val = np.sort(unit(label.flatten()))
    X     = (np.arange(len(y_val))/(len(y_val)-1) )
    mat   = np.concatenate([(X**i).reshape(-1,1) for i in range(degree)], axis=1)
    coef  = np.dot(np.linalg.inv(np.dot(mat.T,mat)), np.dot(mat.T, y_val))
    poly  = sum([coef[i]*(x**i) for i in range(degree)])
    return poly
x = np.arange(100001)/100000
pl.figure(figsize=(14,4))
pl.subplot(131)
pl.plot(x,f_act(x))
pl.plot(np.arange(len(label))/(len(label)-1),np.sort(unit(label.flatten())))
pl.subplot(132)
pl.plot(x, error_function(x, label, 100, 12, 1, 10))
pl.subplot(133)
_,_,_ = pl.hist(label, 100)

# %%
# As usual
Train, Label = unit(reduction), unit(label)
ntrain       = int(0.7*len(reduction))
trainX, trainY, testX, testY = Train[:ntrain], Label[:ntrain], Train[ntrain:], Label[ntrain:]
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
dim = [trainX.shape[1], 30, 30, 30,10, trainY.shape[1]]
rmse1,cc1 = [],[]
for i in range(20):
    prediction   = FFN(trainX, trainY, testX, testY, 0.005, 50, 1024*4, dim, 0)
    rmse1.append(Rmse(prediction, testY))
    cc1.append(cc(prediction, testY))
# Out:
# (73964, 39) (73964, 1) (31700, 39) (31700, 1)
# Training Error: 0.17142448 and Testing Error: 0.154908
# Training Error: 0.09308454 and Testing Error: 0.10482787
# Training Error: 0.06314607 and Testing Error: 0.08835395
# Training Error: 0.057492506 and Testing Error: 0.080302395
# Training Error: 0.05595649 and Testing Error: 0.076627694
# Training Error: 0.09730644 and Testing Error: 0.22016963
# Training Error: 0.08862841 and Testing Error: 0.131635
# Training Error: 0.06070081 and Testing Error: 0.09113699
# Training Error: 0.058564603 and Testing Error: 0.08430061
# Training Error: 0.05795296 and Testing Error: 0.07699265
# Training Error: 0.12342756 and Testing Error: 0.13831753
# Training Error: 0.06870532 and Testing Error: 0.109207705
# Training Error: 0.09424676 and Testing Error: 0.0957232
# Training Error: 0.09172993 and Testing Error: 0.08386226
# Training Error: 0.08829195 and Testing Error: 0.079850145
# Training Error: 0.2684803 and Testing Error: 0.14996578
# Training Error: 0.11981118 and Testing Error: 0.17020099
# Training Error: 0.10050786 and Testing Error: 0.09286384
# Training Error: 0.09467267 and Testing Error: 0.08116512
# Training Error: 0.09070538 and Testing Error: 0.07754032
# Training Error: 0.18427904 and Testing Error: 0.16280444
# Training Error: 0.11346091 and Testing Error: 0.16063155
# Training Error: 0.12614813 and Testing Error: 0.11342744
# Training Error: 0.097615115 and Testing Error: 0.091045946
# Training Error: 0.08531375 and Testing Error: 0.08142687
# Training Error: 0.25714776 and Testing Error: 0.36483985
# Training Error: 0.10441561 and Testing Error: 0.14411208
# Training Error: 0.10918983 and Testing Error: 0.097848475
# Training Error: 0.099483624 and Testing Error: 0.08607169
# Training Error: 0.0944019 and Testing Error: 0.08201113
# Training Error: 0.1323138 and Testing Error: 0.25662604
# Training Error: 0.15587969 and Testing Error: 0.16473669
# Training Error: 0.11981398 and Testing Error: 0.17170618
# Training Error: 0.10675491 and Testing Error: 0.084409334
# Training Error: 0.094069235 and Testing Error: 0.07759567

# %%
np.sort(rmse1)[:10].mean(), np.sort(rmse2)[:10].mean(), np.sort(cc1)[10:].mean(), np.sort(cc2)[10:].mean()
# Out:
# (1236.719518910847, 1262.619419192665, 0.884216012937683, 0.8850585231694483)

# %%
# As usual
Train, Label = unit(reduction), unit(label)
ntrain       = int(0.7*len(reduction))
trainX, trainY, testX, testY = Train[:ntrain], Label[:ntrain], Train[ntrain:], Label[ntrain:]
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
dim = [trainX.shape[1], 30, 30, 30,10, trainY.shape[1]]
prediction   = FFN(trainX, trainY, testX, testY, 0.005, 50, 1024*4, dim, 0)
Figure(testY, prediction, 50)
# Out:
# (73964, 39) (73964, 1) (31700, 39) (31700, 1)
# Training Error: 0.2097919 and Testing Error: 0.37543708
# Training Error: 0.07821566 and Testing Error: 0.12762377
# Training Error: 0.07283392 and Testing Error: 0.100189775
# Training Error: 0.06632902 and Testing Error: 0.086475834
# Training Error: 0.064010255 and Testing Error: 0.080610685
# RMSE: 0.0778
# real RMSE: 1317.9062
# CC: 0.8639

# %%
# Apply error function
Train, Label = unit(reduction), unit(label)
ntrain       = int(0.7*len(reduction))
trainX, trainY, testX, testY = Train[:ntrain], Label[:ntrain], Train[ntrain:], Label[ntrain:]
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
dim = [trainX.shape[1], 30, 30, 30,10, trainY.shape[1]]
prediction   = FFN(trainX, trainY, testX, testY, 0.005, 50, 1024*4, dim, 1)
Figure(testY, prediction, 50)
# Out:
# (73964, 39) (73964, 1) (31700, 39) (31700, 1)
# Training Error: 0.22341037 and Testing Error: 0.17055888
# Training Error: 0.13932146 and Testing Error: 0.18142897
# Training Error: 0.10944141 and Testing Error: 0.09400595
# Training Error: 0.099572405 and Testing Error: 0.08344929
# Training Error: 0.09530127 and Testing Error: 0.08014276
# RMSE: 0.0787
# real RMSE: 1332.926
# CC: 0.8794
